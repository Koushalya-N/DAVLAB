# %%
import numpy as np
import pandas as pd
arr=np.array([10,20,30,40,50])
print("array",arr)
print("mean",arr.mean())
print("Reshaped 2D \n",arr.reshape(5,1))
print("sliceed(index 1 to 3):",arr[1:4])
data={"name":["ravi","asha","mera","karan"],"marks":[88,72,91,65],"branch":["cse","ise","ece","cse"]}
df=pd.DataFrame(data)
print(df)
print("\nfirst 2 rows:\n",df.iloc[0:2])
print("\nmarks column:\n",df["marks"])
print("\nrows where marks >70:\n",df[df["marks"]>70])
# Out:
# array [10 20 30 40 50]
# mean 30.0
# Reshaped 2D
#  [[10]
#  [20]
#  [30]
#  [40]
#  [50]]
# sliceed(index 1 to 3): [20 30 40]
#     name  marks branch
# 0   ravi     88    cse
# 1   asha     72    ise
# 2   mera     91    ece
# 3  karan     65    cse
#
# first 2 rows:
#     name  marks branch
# 0  ravi     88    cse
# 1  asha     72    ise
#
# marks column:
#  0    88
# 1    72
# 2    91
# 3    65
# Name: marks, dtype: int64
#
# rows where marks >70:
#     name  marks branch
# 0  ravi     88    cse
# 1  asha     72    ise
# 2  mera     91    ece

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\user\Desktop\student_performance.csv")
df.head()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade
# 0                  3.8         97.9     A
# 1                  2.5         83.9     B
# 2                  5.3        100.0     A
# 3                  7.0        100.0     A
# 4                  6.9         92.0     A

# %%
df.head()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade
# 0                  3.8         97.9     A
# 1                  2.5         83.9     B
# 2                  5.3        100.0     A
# 3                  7.0        100.0     A
# 4                  6.9         92.0     A

# %%
df.tail()
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 999995                  4.8        100.0     A
# 999996                  6.7         88.3     A
# 999997                  5.8         87.9     A
# 999998                  5.3        100.0     A
# 999999                  4.1        100.0     A

# %%
df.shape
# Out:
# (1000000, 6)

# %%
df.columns
# Out:
# Index(['student_id', 'weekly_self_study_hours', 'attendance_percentage',
#        'class_participation', 'total_score', 'grade'],
#       dtype='str')

# %%
df.dtypes
# Out:
# student_id                   int64
# weekly_self_study_hours    float64
# attendance_percentage      float64
# class_participation        float64
# total_score                float64
# grade                          str
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 1                2                     14.0                   80.0
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 4                5                     13.4                   81.9
# ...            ...                      ...                    ...
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 0                       3.8         97.9     A
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 1                2                     14.0                   80.0
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 4                5                     13.4                   81.9
# ...            ...                      ...                    ...
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 0                       3.8         97.9     A
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 1                2                     14.0                   80.0
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 4                5                     13.4                   81.9
# ...            ...                      ...                    ...
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 0                       3.8         97.9     A
# ...

# %%
df.isnull().sum()
# Out:
# student_id                 0
# weekly_self_study_hours    0
# attendance_percentage      0
# class_participation        0
# total_score                0
# grade                      0
# dtype: int64

# %%
df.dropna()
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 1                2                     14.0                   80.0
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 4                5                     13.4                   81.9
# ...            ...                      ...                    ...
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 0                       3.8         97.9     A
# 1                       2.5         83.9     B
# ...

# %%
df.fillna(0)
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 1                2                     14.0                   80.0
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 4                5                     13.4                   81.9
# ...            ...                      ...                    ...
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 0                       3.8         97.9     A
# 1                       2.5         83.9     B
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 999995    False
# 999996    False
# 999997    False
# 999998    False
# 999999    False
# Length: 1000000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().mean()*100
# Out:
# student_id                 0.0
# weekly_self_study_hours    0.0
# attendance_percentage      0.0
# class_participation        0.0
# total_score                0.0
# grade                      0.0
# dtype: float64

# %%
df.drop_duplicates()
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 1                2                     14.0                   80.0
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 4                5                     13.4                   81.9
# ...            ...                      ...                    ...
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 0                       3.8         97.9     A
# 1                       2.5         83.9     B
# ...

# %%
df["total_score"].mean()
# Out:
# np.float64(84.2838453)

# %%
df["total_score"].median()
# Out:
# np.float64(87.5)

# %%
df["total_score"].mode()
# Out:
# 0    100.0
# Name: total_score, dtype: float64

# %%
df["total_score"].var()
# Out:
# np.float64(238.17652523219314)

# %%
df["total_score"].std()
# Out:
# np.float64(15.432968775714967)

# %%
df["total_score"].min()
# Out:
# np.float64(9.4)

# %%
df["total_score"].max()
# Out:
# np.float64(100.0)

# %%
df["total_score"].count()
# Out:
# np.int64(1000000)

# %%
df["total_score"].unique()
# Out:
# array([ 97.9,  83.9, 100. ,  92. ,  97.5,  96.1,  69.8,  80.3,  66.4,
#         72.5,  95.2,  60.9,  52.1,  73.5,  63. ,  75.4,  57.9,  79. ,
#         76.3,  58.7,  68.3,  97.2,  68.4,  63.6,  89.2,  77.4,  82.6,
#         71.9,  97.4,  61.6,  99.5,  50.1,  56.7,  84. ,  55.9,  89.6,
#         78.7,  90.3,  71. ,  51.1,  82.7,  91. ,  92.7,  76.9,  91.9,
#         89.5,  71.2,  81.9,  67.1,  69.9,  96.5,  80.4,  92.2,  83.6,
#         78.8,  93.2,  84.5,  47.4,  90.8,  87.7,  91.7,  54.6,  81. ,
#         79.5,  62.3,  64.9,  93.3,  98.4,  69.2,  93.9,  79.7,  86.6,
#         72. ,  73.6,  67.3,  73.1,  63.9,  72.9,  73.4,  68.1,  86.1,
#         83. ,  77.7,  93.6,  43.5,  93.8,  78.9,  84.2,  73.2,  95.4,
#         92.1,  76.7,  74.1,  74.2,  74. ,  72.6,  74.8,  54.7,  50.6,
#         86.8,  92.6,  97.3,  70.6,  54.8,  95. ,  58.2,  87.9,  86.2,
#         58.9,  83.5,  90.2,  94.4,  85.4,  92.4,  79.6,  95.8,  75.8,
# ...

# %%
df["total_score"].nunique()
# Out:
# 824

# %%
df["total_score"].value_counts()
# Out:
# total_score
# 100.0    268121
# 86.0       2051
# 88.7       2037
# 88.5       2036
# 86.2       2035
#           ...
# 20.0          1
# 18.4          1
# 19.4          1
# 18.2          1
# 22.5          1
# Name: count, Length: 824, dtype: int64

# %%
df["total_score"]
# Out:
# 0          97.9
# 1          83.9
# 2         100.0
# 3         100.0
# 4          92.0
#           ...
# 999995    100.0
# 999996     88.3
# 999997     87.9
# 999998    100.0
# 999999    100.0
# Name: total_score, Length: 1000000, dtype: float64

# %%
df[df["total_score"]>30]
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 1                2                     14.0                   80.0
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 4                5                     13.4                   81.9
# ...            ...                      ...                    ...
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 0                       3.8         97.9     A
# 1                       2.5         83.9     B
# ...

# %%
df.sort_values("total_score")
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 114309      114310                      0.0                   72.5
# 384794      384795                      0.0                   84.0
# 128034      128035                      0.0                   74.4
# 430442      430443                      1.5                   70.5
# 2118          2119                      0.0                   79.8
# ...            ...                      ...                    ...
# 999995      999996                     18.0                   95.5
# 999998      999999                     25.3                   90.0
# 20              21                     25.3                   89.3
# 17              18                     17.2                   74.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 114309                  3.8          9.4     F
# 384794                  5.0         12.2     F
# ...

# %%
df.rename(columns={"total_score":"total_score"})
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 1                2                     14.0                   80.0
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 4                5                     13.4                   81.9
# ...            ...                      ...                    ...
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 0                       3.8         97.9     A
# 1                       2.5         83.9     B
# ...

# %%
df.drop("total_score", axis=1)
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     0.38                   95.6
# 1                2                     0.25                   80.0
# 2                3                     0.53                   86.3
# 3                4                     0.70                   70.2
# 4                5                     0.69                   81.9
# ...            ...                      ...                    ...
# 999995      999996                     0.48                   95.5
# 999996      999997                     0.67                   82.7
# 999997      999998                     0.58                   85.1
# 999998      999999                     0.53                   90.0
# 999999     1000000                     0.41                   84.6
#
#         class_participation grade
# 0                       3.8     A
# 1                       2.5     B
# 2                       5.3     A
# ...

# %%
df.groupby("student_id")

# %%
df.groupby("student_id")["class_participation"].mean()
# Out:
# student_id
# 1          3.8
# 2          2.5
# 3          5.3
# 4          7.0
# 5          6.9
#           ...
# 999996     4.8
# 999997     6.7
# 999998     5.8
# 999999     5.3
# 1000000    4.1
# Name: class_participation, Length: 1000000, dtype: float64
