# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Velu K R\Downloads\archive (1)\synthetic_dataset.csv")
df.head()
# Out:
#   Category   Price    Rating         Stock  Discount
# 0      NaN  5548.0  1.870322           NaN       0.0
# 1      NaN  3045.0  4.757798           NaN      38.0
# 2      NaN  4004.0       NaN      In Stock       0.0
# 3      NaN  4808.0  1.492085           NaN      33.0
# 4      NaN  1817.0       NaN  Out of Stock      23.0

# %%
df['Price']=df['Price'].fillna(df['Price'].mean())
print(df)
# Out:
#      Category       Price    Rating         Stock  Discount
# 0         NaN  5548.00000  1.870322           NaN       0.0
# 1         NaN  3045.00000  4.757798           NaN      38.0
# 2         NaN  4004.00000       NaN      In Stock       0.0
# 3         NaN  4808.00000  1.492085           NaN      33.0
# 4         NaN  1817.00000       NaN  Out of Stock      23.0
# ...       ...         ...       ...           ...       ...
# 4357      NaN  4436.00000  4.728335           NaN      49.0
# 4358        B  6236.00000       NaN  Out of Stock       4.0
# 4359      NaN  3283.00000       NaN  Out of Stock       9.0
# 4360        D  2999.00000  4.425995           NaN      40.0
# 4361      NaN  5016.97063  2.184471           NaN       0.0
#
# [4362 rows x 5 columns]

# %%
import pandas as pd

data = {
    'Name': ['Anu', 'Ravi', 'Priya', 'Kiran', 'Meena', 'Arjun'],
    'Age': [21, 22, None, 23, 21, None],
    'Salary': [25000, None, 30000, 28000, None, 32000],
    'Department': ['CSE', 'ECE', 'CSE', None, 'ISE', 'ECE'],
    'City': ['Mysore', 'Bangalore', 'Mysore', 'Hubli', 'Bangalore', 'Mysore']
}

df = pd.DataFrame(data)

df['Salary'] = df['Salary'].fillna(df['Salary'].median())

print(df)
# Out:
#     Name   Age   Salary Department       City
# 0    Anu  21.0  25000.0        CSE     Mysore
# 1   Ravi  22.0  29000.0        ECE  Bangalore
# 2  Priya   NaN  30000.0        CSE     Mysore
# 3  Kiran  23.0  28000.0        NaN      Hubli
# 4  Meena  21.0  29000.0        ISE  Bangalore
# 5  Arjun   NaN  32000.0        ECE     Mysore

# %%
import pandas as pd

data = {
    'Student': ['Anu', 'Ravi', 'Priya', 'Kiran', 'Meena'],
    'Department': ['CSE', 'ECE', None, 'ISE', None]
}

df = pd.DataFrame(data)

print("Before Forward Fill:")
print(df)

df['Department'] = df['Department'].ffill()

print("\nAfter Forward Fill:")
print(df)
# Out:
# Before Forward Fill:
#   Student Department
# 0     Anu        CSE
# 1    Ravi        ECE
# 2   Priya        NaN
# 3   Kiran        ISE
# 4   Meena        NaN
#
# After Forward Fill:
#   Student Department
# 0     Anu        CSE
# 1    Ravi        ECE
# 2   Priya        ECE
# 3   Kiran        ISE
# 4   Meena        ISE

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.9.1)
# Requirement already satisfied: numpy>=1.24.1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (2.5.3)
# Requirement already satisfied: scipy>=1.10.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (1.18.1)
# Requirement already satisfied: joblib>=1.4.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (1.6.0)
# Requirement already satisfied: narwhals>=2.0.1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (2.26.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (3.7.0)
# Requirement already satisfied: cloudpickle>=3.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from joblib>=1.4.0->scikit-learn) (3.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

data = {
    'Name': ['Anu', 'Ravi', 'Priya', 'Kiran'],
    'Department': ['CSE', 'ECE', 'ISE', 'CSE']
}

df = pd.DataFrame(data)

encoder = LabelEncoder()
df['Department_Encoded'] = encoder.fit_transform(df['Department'])

print(df)
print(encoder.classes_)
# Out:
#     Name Department  Department_Encoded
# 0    Anu        CSE                   0
# 1   Ravi        ECE                   1
# 2  Priya        ISE                   2
# 3  Kiran        CSE                   0
# ['CSE' 'ECE' 'ISE']

# %%
data = {
    'Name': ['Anu', 'Ravi', 'Priya', 'Kiran'],
    'Department': ['CSE', 'ECE', 'ISE', 'CSE']
}
df = pd.DataFrame(data)
encoded_df = pd.get_dummies(df, columns=['Department'])
print(encoded_df)
# Out:
#     Name  Department_CSE  Department_ECE  Department_ISE
# 0    Anu            True           False           False
# 1   Ravi           False            True           False
# 2  Priya           False           False            True
# 3  Kiran            True           False           False

# %%
encoded_df = pd.get_dummies(
    df,
    columns=['Department'],
    dtype=int
)
print(encoded_df)
# Out:
#     Name  Department_CSE  Department_ECE  Department_ISE
# 0    Anu               1               0               0
# 1   Ravi               0               1               0
# 2  Priya               0               0               1
# 3  Kiran               1               0               0
